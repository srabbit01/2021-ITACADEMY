# %% [markdown]
# # CNN(Convolution Neural Network)
# ![image-2.png](attachment:image-2.png)
# - 컨볼루션(합성곱)을 탑재한 신경망 네트워크
# - 필터를 적용하여 특성을 추출하는 것
# ![image.png](attachment:image.png)
#   - Convolution: 3차원으로 분리하기
#   - pooling: 합치기
#
#   ** 이미지는 원래 3차원 = 가로,세로,색깔

# %%
ANN RNN ISTE
